# %%
from abc import ABC, abstractmethod
import os
import glob
from collections import deque
from time import time
from datetime import timedelta
import pickle
from base64 import b64encode
import math
import numpy as np
np.bool8 = np.bool
import torch
from torch import nn
from torch.distributions import Normal
import torch.nn.functional as F
from torch.optim.lr_scheduler import LinearLR
import gymnasium as gym
from gymnasium.wrappers import RecordVideo
import matplotlib.pyplot as plt
from IPython.display import HTML
from pytorch_grad_cam import GradCAM
from pytorch_grad_cam.utils.image import show_cam_on_image
from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget

# %matplotlib inline

# %%
def play_mp4(folder_path="videos"):
    """ColabでMP4動画を表示します"""
    video_files = glob.glob(os.path.join(folder_path, "*.mp4"))
    if not video_files:
        print(f"動画ファイルがフォルダ '{folder_path}' に見つかりません。")
        return

    latest_file = max(video_files, key=os.path.getctime)
    print(f"表示中の動画: {latest_file}")

    with open(latest_file, 'rb') as f:
        video_data = f.read()

    video_url = f"data:video/mp4;base64,{b64encode(video_data).decode()}"
    return HTML(f"""
    <video width=600 controls>
        <source src="{video_url}" type="video/mp4">
    </video>
    """)

# %%
def preprocess_state(state, device):
    """(高さ, 幅, チャンネル)のNumpy配列を(1, チャンネル, 高さ, 幅)のTensorに変換"""
    state_tensor = torch.tensor(state, dtype=torch.float32, device=device).permute(2, 0, 1) / 255.0
    return state_tensor.unsqueeze(0)

# %%
env = gym.make('CarRacing-v3', render_mode='rgb_array')
video_folder = "random_run_videos"
env = RecordVideo(env, video_folder, episode_trigger=lambda e: True)

print('observation space: ', env.observation_space)
print('action space: ', env.action_space)

env.reset()
done = False

while (not done):
  action = env.action_space.sample()
  obs, reward, terminated, truncated, info = env.step(action)
  done = terminated or truncated

env.close()
# Out:
# /opt/miniconda3/envs/car-racing-env/lib/python3.10/site-packages/gymnasium/wrappers/rendering.py:293: UserWarning: WARN: Overwriting existing videos at /Users/todayuto/Downloads/random_run_videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# observation space:  Box(0, 255, (96, 96, 3), uint8)
# action space:  Box([-1.  0.  0.], 1.0, (3,), float32)

# %%
play_mp4(video_folder)
# Out:
# 表示中の動画: random_run_videos/rl-video-episode-0.mp4
#     <video width=600 controls>
#         <source src="data:video/mp4;base64,..." type="video/mp4">
#     </video>

# %%
class Trainer:
    """学習全体を管理するクラス"""
    def __init__(self, env, env_test, algo, seed=0, num_steps=10**6, eval_interval=10**4, num_eval_episodes=3, model_dir='best_model'):
        self.env = env
        self.env_test = env_test
        self.algo = algo
        self.seed = seed
        self.returns = {'step': [], 'return': []}
        self.num_steps = num_steps
        self.eval_interval = eval_interval
        self.num_eval_episodes = num_eval_episodes
        self.model_dir = model_dir
        self.best_mean_return = -float('inf')

    def train(self):
        self.start_time = time()
        t = 0
        state, _ = self.env.reset(seed=self.seed)
        for steps in range(1, self.num_steps + 1):
            state, t = self.algo.step(self.env, state, t, steps)
            if self.algo.is_update(steps):
                self.algo.update()
            if steps % self.eval_interval == 0:
                self.evaluate(steps)

    def evaluate(self, steps):
        returns = []
        for _ in range(self.num_eval_episodes):
            state, _ = self.env_test.reset(seed=2**31 - 1 - self.seed)
            episode_return = 0.0
            done = False
            while not done:
                action = self.algo.exploit(state)
                state, reward, terminated, truncated, _ = self.env_test.step(action)
                done = terminated or truncated
                episode_return += reward
            returns.append(episode_return)

        mean_return = np.mean(returns)
        self.returns['step'].append(steps)
        self.returns['return'].append(mean_return)
        print(f'Num steps: {steps:<6}   Return: {mean_return:<5.1f}   Time: {self.time}')

        if mean_return > self.best_mean_return:
            self.best_mean_return = mean_return
            print(f"最高スコアを記録: {self.best_mean_return:.1f}")
            self.algo.save_models(self.model_dir)

    def visualize(self, folder="final_agent_videos"):
        """学習済みエージェントの動画を記録・表示"""
        vis_env = gym.make('CarRacing-v3', render_mode='rgb_array')
        vis_env = RecordVideo(vis_env, folder, episode_trigger=lambda e: True)
        state, _ = vis_env.reset(seed=self.seed)
        done = False
        while not done:
            action = self.algo.exploit(state)
            state, _, terminated, truncated, _ = vis_env.step(action)
            done = terminated or truncated
        vis_env.close()
        return play_mp4(folder)

    def plot(self):
        """学習曲線をプロット"""
        fig = plt.figure(figsize=(8, 6))
        plt.plot(self.returns['step'], self.returns['return'])
        plt.xlabel('Steps', fontsize=18)
        plt.ylabel('Return', fontsize=18)
        plt.yticks(np.arange(-100, 1001, 100))
        plt.title(f'Learning Curve for {self.env.unwrapped.spec.id}', fontsize=20)
        plt.grid(True)
        plt.tight_layout()
        plt.show()

    @property
    def time(self):
        return str(timedelta(seconds=int(time() - self.start_time)))

# %%
class Algorithm(ABC):
    @abstractmethod
    def explore(self, state):
        pass
    @abstractmethod
    def exploit(self, state):
        pass
    @abstractmethod
    def is_update(self, steps):
        pass
    @abstractmethod
    def step(self, env, state, t, steps):
        pass
    @abstractmethod
    def update(self):
        pass

# %%
class RunningMeanStd:
    def __init__(self, shape=(), epsilon=1e-8):
        self.mean = np.zeros(shape, 'float64')
        self.var = np.ones(shape, 'float64')
        self.count = epsilon

    def update(self, x):
        batch_mean = np.mean(x, axis=0)
        batch_var = np.var(x, axis=0)
        batch_count = x.shape[0]

        delta = batch_mean - self.mean
        tot_count = self.count + batch_count

        new_mean = self.mean + delta * batch_count / tot_count
        m_a = self.var * self.count
        m_b = batch_var * batch_count
        m_2 = m_a + m_b + np.square(delta) * self.count * batch_count / tot_count
        new_var = m_2 / tot_count

        self.mean = new_mean
        self.var = new_var
        self.count = tot_count

# %%
def calculate_log_pi(log_stds, noises, actions):
    log_pis = -0.5 * math.log(2 * math.pi) * log_stds.size(-1) - log_stds.sum(dim=-1, keepdim=True) - (0.5 * noises.pow(2)).sum(dim=-1, keepdim=True)
    log_pis -= torch.log(1 - actions.pow(2) + 1e-6).sum(dim=-1, keepdim=True)

    return log_pis

# %%
def reparameterize(means, log_stds):
    stds = log_stds.exp()
    noises = torch.randn_like(means)
    us = means + noises * stds
    actions = torch.tanh(us)

    log_pis = calculate_log_pi(log_stds, noises, actions)

    return actions, log_pis

# %%
def atanh(x):
    return 0.5 * (torch.log(1 + x + 1e-6) - torch.log(1 - x + 1e-6))


def evaluate_lop_pi(means, log_stds, actions):
    noises = (atanh(actions) - means) / (log_stds.exp() + 1e-8)
    return calculate_log_pi(log_stds, noises, actions)

# %%
class CNN(nn.Module):
    def __init__(self, input_channels=3):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv2d(input_channels, 32, kernel_size=8, stride=4, padding=0),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2, padding=0),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=0),
            nn.ReLU(),
            nn.Flatten(),
        )

    def forward(self, states):
        return self.net(states)

# %%
class PPOActor(nn.Module):
    def __init__(self, cnn_output_dim, action_shape):
        super().__init__()
        self.fc = nn.Sequential(
            nn.Linear(cnn_output_dim, 256),
            nn.ReLU(),
            nn.Linear(256, action_shape[0]),
        )
        self.log_stds = nn.Parameter(torch.zeros(1, action_shape[0]))

    def forward(self, features):
        return torch.tanh(self.fc(features))

    def sample(self, features):
        return reparameterize(self.fc(features), self.log_stds)

# %%
class PPOCritic(nn.Module):
    def __init__(self, cnn_output_dim):
        super().__init__()
        self.fc = nn.Sequential(
            nn.Linear(cnn_output_dim, 256),
            nn.ReLU(),
            nn.Linear(256, 1),
        )

    def forward(self, features):
        return self.fc(features)

# %%
def calculate_advantage(values, rewards, dones, next_values, gamma=0.995, lambd=0.997):

    # TD誤差を計算する．
    deltas = rewards + gamma * next_values * (1 - dones) - values

    # GAEを初期化する．
    advantages = torch.empty_like(rewards)

    # 終端ステップを計算する．
    advantages[-1] = deltas[-1]

    # 終端ステップの1つ前から，順番にGAEを計算していく．
    for t in reversed(range(rewards.size(0) - 1)):
        advantages[t] = deltas[t] + gamma * lambd * (1 - dones[t]) * advantages[t + 1]

    # 状態価値のターゲットをλ-収益として計算する．
    targets = advantages + values

    # GAEを標準化する．
    advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)

    return targets, advantages

# %%
class RolloutBuffer:
    def __init__(self, buffer_size, state_shape, action_shape, device):
        self.states = torch.empty((buffer_size, *state_shape), dtype=torch.uint8, device=device)
        self.actions = torch.empty((buffer_size, *action_shape), dtype=torch.float32, device=device)
        self.rewards = torch.empty((buffer_size, 1), dtype=torch.float32, device=device)
        self.dones = torch.empty((buffer_size, 1), dtype=torch.float32, device=device)
        self.log_pis = torch.empty((buffer_size, 1), dtype=torch.float32, device=device)
        self._p = 0
        self.buffer_size = buffer_size

    def append(self, state, action, reward, done, log_pi):
        self.states[self._p].copy_(torch.from_numpy(state))
        self.actions[self._p].copy_(torch.from_numpy(action))
        self.rewards[self._p] = float(reward)
        self.dones[self._p] = float(done)
        self.log_pis[self._p] = float(log_pi)
        self._p = (self._p + 1) % self.buffer_size

    def get(self):
        assert self._p == 0, 'Buffer needs to be full before training.'
        return self.states, self.actions, self.rewards, self.dones, self.log_pis

# %%
class PPO(Algorithm):
    def __init__(self, state_shape, action_shape, device, seed=0,
                 batch_size=256, gamma=0.99, lr=3e-5,
                 rollout_length=2048, num_updates=10, clip_eps=0.2, lambd=0.95,
                 coef_ent=0.01, max_grad_norm=0.5):
        super().__init__()
        torch.manual_seed(seed)
        if device.type == 'cuda': torch.cuda.manual_seed(seed)
        np.random.seed(seed)

        self.buffer = RolloutBuffer(rollout_length, state_shape, action_shape, device)
        self.device = device

        dummy_state = torch.zeros(1, state_shape[2], state_shape[0], state_shape[1], device=device)
        self.cnn = CNN(input_channels=state_shape[2]).to(device)
        cnn_output_dim = self.cnn(dummy_state).shape[-1]
        self.actor = PPOActor(cnn_output_dim, action_shape).to(device)
        self.critic = PPOCritic(cnn_output_dim).to(device)
        self.optim = torch.optim.Adam(list(self.cnn.parameters()) + list(self.actor.parameters()) + list(self.critic.parameters()), lr=lr)

        self.batch_size = batch_size
        self.gamma = gamma
        self.rollout_length = rollout_length
        self.num_updates = num_updates
        self.clip_eps = clip_eps
        self.lambd = lambd
        self.coef_ent = coef_ent
        self.max_grad_norm = max_grad_norm

        self.off_course_threshold = 100
        self.off_course_counter = 0


    def explore(self, state):
        state_tensor = preprocess_state(state, self.device)
        with torch.no_grad():
            features = self.cnn(state_tensor)
            action, log_pi = self.actor.sample(features)
        return action.cpu().numpy()[0], log_pi.item()

    def exploit(self, state):
        state_tensor = preprocess_state(state, self.device)
        with torch.no_grad():
            features = self.cnn(state_tensor)
            action = self.actor(features)
        return action.cpu().numpy()[0]

    def is_update(self, steps):
        return steps % self.rollout_length == 0

    def step(self, env, state, t, steps):
        t += 1
        action, log_pi = self.explore(state)
        next_state, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated

        if reward < 0:
            self.off_course_counter += 1
        else:
            self.off_course_counter = 0

        if self.off_course_counter >= self.off_course_threshold:
            done = True
            reward = -100

        done_masked = done if not truncated else False
        self.buffer.append(state, action, reward, done_masked, log_pi)

        if done:
            t = 0
            next_state, _ = env.reset()
            self.off_course_counter = 0

        return next_state, t

    def update(self):
        states, actions, rewards, dones, log_pis_old = self.buffer.get()
        processed_states = states.float().permute(0, 3, 1, 2) / 255.0

        with torch.no_grad():
            features = self.cnn(processed_states)
            values = self.critic(features)
            next_features = self.cnn(torch.roll(processed_states, -1, 0))
            next_values = self.critic(next_features)

        targets, advantages = calculate_advantage(values, rewards, dones, next_values, self.gamma, self.lambd)

        for _ in range(self.num_updates):
            indices = np.random.permutation(self.rollout_length)
            for start in range(0, self.rollout_length, self.batch_size):
                idx = indices[start:start+self.batch_size]
                features_batch = self.cnn(processed_states[idx])

                loss_critic = (self.critic(features_batch) - targets[idx]).pow(2).mean()

                log_pis = evaluate_lop_pi(self.actor.fc(features_batch), self.actor.log_stds, actions[idx])
                mean_entropy = -log_pis.mean()
                ratios = (log_pis - log_pis_old[idx]).exp()
                loss_actor1 = -ratios * advantages[idx]
                loss_actor2 = -torch.clamp(ratios, 1.0 - self.clip_eps, 1.0 + self.clip_eps) * advantages[idx]
                loss_actor = torch.max(loss_actor1, loss_actor2).mean() - self.coef_ent * mean_entropy

                total_loss = loss_actor + 0.5 * loss_critic

                self.optim.zero_grad()
                total_loss.backward()
                nn.utils.clip_grad_norm_(self.cnn.parameters(), self.max_grad_norm)
                nn.utils.clip_grad_norm_(self.actor.parameters(), self.max_grad_norm)
                nn.utils.clip_grad_norm_(self.critic.parameters(), self.max_grad_norm)
                self.optim.step()

    def save_models(self, save_dir):
        if not os.path.exists(save_dir):
            os.makedirs(save_dir)
        torch.save(self.cnn.state_dict(), os.path.join(save_dir, 'cnn.pth'))
        torch.save(self.actor.state_dict(), os.path.join(save_dir, 'actor.pth'))
        torch.save(self.critic.state_dict(), os.path.join(save_dir, 'critic.pth'))
        print(f"モデルを {save_dir} に保存しました。")

    def load_models(self, load_dir):
        self.cnn.load_state_dict(torch.load(os.path.join(load_dir, 'cnn.pth')))
        self.actor.load_state_dict(torch.load(os.path.join(load_dir, 'actor.pth')))
        self.critic.load_state_dict(torch.load(os.path.join(load_dir, 'critic.pth')))
        print(f"モデルを {load_dir} から読み込みました。")

# %%
SEED = 0
NUM_STEPS = 5 * 10**5
EVAL_INTERVAL = 2048

env = gym.make('CarRacing-v3', render_mode='rgb_array', max_episode_steps=1000)
env_test = gym.make('CarRacing-v3', render_mode='rgb_array', max_episode_steps=1000)

algo = PPO(
    state_shape=env.observation_space.shape,
    action_shape=env.action_space.shape,
    seed=SEED,
    device=torch.device("cuda" if torch.cuda.is_available() else "cpu")
)

trainer = Trainer(
    env=env,
    env_test=env_test,
    algo=algo,
    seed=SEED,
    num_steps=NUM_STEPS,
    eval_interval=EVAL_INTERVAL,
    model_dir='model_ppo_1'
)

# %%
trainer.train()
# Out:
# Num steps: 2048     Return: -61.9   Time: 0:00:31
# 最高スコアを記録: -61.9
# モデルを best_model_3 に保存しました。
# Num steps: 4096     Return: -23.9   Time: 0:01:03
# 最高スコアを記録: -23.9
# モデルを best_model_3 に保存しました。
# Num steps: 6144     Return: 169.9   Time: 0:01:37
# 最高スコアを記録: 169.9
# モデルを best_model_3 に保存しました。
# Num steps: 8192     Return: -57.0   Time: 0:02:00
# Num steps: 10240    Return: -53.0   Time: 0:02:21
# Num steps: 12288    Return: -61.9   Time: 0:02:54
# Num steps: 14336    Return: 41.9    Time: 0:03:28
# Num steps: 16384    Return: -75.8   Time: 0:04:00
# Num steps: 18432    Return: -41.2   Time: 0:04:30
# Num steps: 20480    Return: -75.8   Time: 0:05:03
# Num steps: 22528    Return: 176.8   Time: 0:05:37
# 最高スコアを記録: 176.8
# モデルを best_model_3 に保存しました。
# Num steps: 24576    Return: 10.7    Time: 0:06:11
# Num steps: 26624    Return: 221.8   Time: 0:06:46
# 最高スコアを記録: 221.8
# モデルを best_model_3 に保存しました。
# Num steps: 28672    Return: 31.5    Time: 0:07:23
# Num steps: 30720    Return: 31.5    Time: 0:07:58
# Num steps: 32768    Return: 183.7   Time: 0:08:32
# Num steps: 34816    Return: 66.1    Time: 0:09:06
# Num steps: 36864    Return: 235.6   Time: 0:09:44
# 最高スコアを記録: 235.6
# モデルを best_model_3 に保存しました。
# Num steps: 38912    Return: 225.3   Time: 0:10:25
# Num steps: 40960    Return: 252.9   Time: 0:11:01
# 最高スコアを記録: 252.9
# モデルを best_model_3 に保存しました。
# Num steps: 43008    Return: 716.6   Time: 0:11:49
# 最高スコアを記録: 716.6
# モデルを best_model_3 に保存しました。
# Num steps: 45056    Return: 242.6   Time: 0:12:23
# Num steps: 47104    Return: 730.4   Time: 0:12:57
# 最高スコアを記録: 730.4
# モデルを best_model_3 に保存しました。
# Num steps: 49152    Return: 671.6   Time: 0:13:31
# Num steps: 51200    Return: 796.2   Time: 0:14:04
# 最高スコアを記録: 796.2
# モデルを best_model_3 に保存しました。
# Num steps: 53248    Return: 304.8   Time: 0:14:39
# Num steps: 55296    Return: 273.7   Time: 0:15:12
# Num steps: 57344    Return: 246.0   Time: 0:15:46
# Num steps: 59392    Return: 249.5   Time: 0:16:20
# Num steps: 61440    Return: 242.6   Time: 0:16:55
# Num steps: 63488    Return: 93.8    Time: 0:17:30
# Num steps: 65536    Return: 194.1   Time: 0:18:05
# Num steps: 67584    Return: 69.6    Time: 0:18:42
# Num steps: 69632    Return: -23.9   Time: 0:19:17
# Num steps: 71680    Return: -27.3   Time: 0:19:51
# Num steps: 73728    Return: 221.8   Time: 0:20:26
# Num steps: 75776    Return: 190.7   Time: 0:21:02
# Num steps: 77824    Return: 90.3    Time: 0:21:41
# Num steps: 79872    Return: 90.3    Time: 0:22:17
# Num steps: 81920    Return: -3.1    Time: 0:22:53
# Num steps: 83968    Return: -52.9   Time: 0:23:18
# Num steps: 86016    Return: -54.0   Time: 0:23:47
# Num steps: 88064    Return: -87.9   Time: 0:24:20
# Num steps: 90112    Return: 62.6    Time: 0:24:57
# Num steps: 92160    Return: -34.3   Time: 0:25:40
# Num steps: 94208    Return: 17.6    Time: 0:26:30
# Num steps: 96256    Return: -3.1    Time: 0:27:19
# Num steps: 98304    Return: 66.1    Time: 0:27:58
# Num steps: 100352   Return: 187.2   Time: 0:28:40
# Num steps: 102400   Return: 90.3    Time: 0:29:20
# Num steps: 104448   Return: 97.2    Time: 0:30:10
# Num steps: 106496   Return: 83.4    Time: 0:30:52
# Num steps: 108544   Return: -27.3   Time: 0:31:39
# Num steps: 110592   Return: 169.9   Time: 0:32:28
# Num steps: 112640   Return: -27.3   Time: 0:33:12
# Num steps: 114688   Return: 412.1   Time: 0:34:06
# Num steps: 116736   Return: -23.9   Time: 0:34:50
# Num steps: 118784   Return: 208.0   Time: 0:35:37
# Num steps: 120832   Return: 235.6   Time: 0:36:21
# Num steps: 122880   Return: 7.3     Time: 0:37:08
# Num steps: 124928   Return: -23.9   Time: 0:37:54
# Num steps: 126976   Return: 100.7   Time: 0:38:40
# Num steps: 129024   Return: 3.8     Time: 0:39:28
# Num steps: 131072   Return: -10.0   Time: 0:40:16
# Num steps: 133120   Return: 76.5    Time: 0:41:04
# Num steps: 135168   Return: -30.8   Time: 0:41:56
# Num steps: 137216   Return: -41.2   Time: 0:42:40
# Num steps: 139264   Return: -30.8   Time: 0:43:26
# Num steps: 141312   Return: -100.5   Time: 0:44:04
# Num steps: 143360   Return: -55.0   Time: 0:44:53
# Num steps: 145408   Return: -23.9   Time: 0:45:41
# Num steps: 147456   Return: -58.5   Time: 0:46:28
# Num steps: 149504   Return: -123.8   Time: 0:47:09
# Num steps: 151552   Return: -13.5   Time: 0:47:59
# Num steps: 153600   Return: 0.3     Time: 0:48:45
# Num steps: 155648   Return: -41.2   Time: 0:49:27
# Num steps: 157696   Return: -48.1   Time: 0:50:08
# Num steps: 159744   Return: 17.6    Time: 0:50:54
# Num steps: 161792   Return: -41.2   Time: 0:51:48
# Num steps: 163840   Return: -3.1    Time: 0:52:31
# Num steps: 165888   Return: 41.9    Time: 0:53:13
# Num steps: 167936   Return: 3.8     Time: 0:53:55
# Num steps: 169984   Return: 24.6    Time: 0:54:38
# Num steps: 172032   Return: 76.5    Time: 0:55:24
# Num steps: 174080   Return: -3.1    Time: 0:56:07
# Num steps: 176128   Return: 76.5    Time: 0:56:51
# Num steps: 178176   Return: 21.1    Time: 0:57:45
# Num steps: 180224   Return: 187.2   Time: 0:58:30
# Num steps: 182272   Return: 208.0   Time: 0:59:16
# Num steps: 184320   Return: 7.3     Time: 1:00:02
# Num steps: 186368   Return: 156.1   Time: 1:00:45
# Num steps: 188416   Return: 159.5   Time: 1:01:32
# Num steps: 190464   Return: 176.8   Time: 1:02:12
# Num steps: 192512   Return: 287.5   Time: 1:02:53
# Num steps: 194560   Return: 7.3     Time: 1:03:34
# Num steps: 196608   Return: 0.3     Time: 1:04:15
# Num steps: 198656   Return: -65.4   Time: 1:05:02
# Num steps: 200704   Return: 232.2   Time: 1:05:44
# Num steps: 202752   Return: -10.0   Time: 1:06:28
# Num steps: 204800   Return: 156.1   Time: 1:07:18
# Num steps: 206848   Return: -51.6   Time: 1:08:04
# Num steps: 208896   Return: 83.4    Time: 1:08:48
# Num steps: 210944   Return: -13.5   Time: 1:09:29
# Num steps: 212992   Return: 201.0   Time: 1:10:11
# Num steps: 215040   Return: -10.0   Time: 1:10:51
# Num steps: 217088   Return: -30.8   Time: 1:11:43
# Num steps: 219136   Return: -13.5   Time: 1:12:26
# Num steps: 221184   Return: -41.2   Time: 1:13:10
# Num steps: 223232   Return: -41.2   Time: 1:13:55
# Num steps: 225280   Return: -61.9   Time: 1:14:40
# Num steps: 227328   Return: 83.4    Time: 1:15:35
# Num steps: 229376   Return: -65.4   Time: 1:16:25
# Num steps: 231424   Return: -61.9   Time: 1:17:10
# Num steps: 233472   Return: 28.0    Time: 1:17:48
# Num steps: 235520   Return: -41.2   Time: 1:18:26
# Num steps: 237568   Return: 0.3     Time: 1:19:03
# Num steps: 239616   Return: -37.7   Time: 1:19:46
# Num steps: 241664   Return: 10.7    Time: 1:20:30
# Num steps: 243712   Return: 28.0    Time: 1:21:23
# Num steps: 245760   Return: 145.7   Time: 1:22:06
# Num steps: 247808   Return: -37.7   Time: 1:22:47
# Num steps: 249856   Return: -23.9   Time: 1:23:28
# Num steps: 251904   Return: -6.6    Time: 1:24:10
# Num steps: 253952   Return: -20.4   Time: 1:24:49
# Num steps: 256000   Return: 21.1    Time: 1:25:30
# Num steps: 258048   Return: 28.0    Time: 1:26:12
# Num steps: 260096   Return: -17.0   Time: 1:26:54
# Num steps: 262144   Return: -17.0   Time: 1:27:35
# Num steps: 264192   Return: 28.0    Time: 1:28:13
# Num steps: 266240   Return: 0.3     Time: 1:28:56
# Num steps: 268288   Return: -41.2   Time: 1:29:42
# Num steps: 270336   Return: -65.4   Time: 1:30:24
# Num steps: 272384   Return: -55.0   Time: 1:31:05
# Num steps: 274432   Return: 3.8     Time: 1:31:48
# Num steps: 276480   Return: 249.5   Time: 1:32:28
# Num steps: 278528   Return: 214.9   Time: 1:33:08
# Num steps: 280576   Return: 7.3     Time: 1:33:49
# Num steps: 282624   Return: 97.2    Time: 1:34:32
# Num steps: 284672   Return: -65.4   Time: 1:35:11
# Num steps: 286720   Return: -65.4   Time: 1:35:50
# Num steps: 288768   Return: 173.4   Time: 1:36:30
# Num steps: 290816   Return: 284.1   Time: 1:37:11
# Num steps: 292864   Return: 505.5   Time: 1:37:58
# Num steps: 294912   Return: 273.7   Time: 1:38:43
# Num steps: 296960   Return: 709.7   Time: 1:39:24
# Num steps: 299008   Return: 107.6   Time: 1:40:03
# Num steps: 301056   Return: 301.4   Time: 1:40:44
# Num steps: 303104   Return: 228.7   Time: 1:41:30
# Num steps: 305152   Return: 118.0   Time: 1:42:16
# Num steps: 307200   Return: 232.2   Time: 1:43:01
# Num steps: 309248   Return: 228.7   Time: 1:43:44
# Num steps: 311296   Return: 145.7   Time: 1:44:22
# Num steps: 313344   Return: -61.9   Time: 1:44:59
# Num steps: 315392   Return: -61.9   Time: 1:45:41
# Num steps: 317440   Return: 59.2    Time: 1:46:22
# Num steps: 319488   Return: 183.7   Time: 1:47:08
# Num steps: 321536   Return: -13.5   Time: 1:48:02
# Num steps: 323584   Return: 59.2    Time: 1:48:45
# Num steps: 325632   Return: -13.5   Time: 1:49:26
# Num steps: 327680   Return: 79.9    Time: 1:50:05
# Num steps: 329728   Return: 28.0    Time: 1:50:45
# Num steps: 331776   Return: 284.1   Time: 1:51:31
# Num steps: 333824   Return: 273.7   Time: 1:52:17
# Num steps: 335872   Return: -6.6    Time: 1:53:01
# Num steps: 337920   Return: 263.3   Time: 1:53:50
# Num steps: 339968   Return: 10.7    Time: 1:54:35
# Num steps: 342016   Return: 273.7   Time: 1:55:14
# Num steps: 344064   Return: 104.2   Time: 1:55:57
# Num steps: 346112   Return: -17.0   Time: 1:56:41
# Num steps: 348160   Return: 429.4   Time: 1:57:37
# Num steps: 350208   Return: 682.0   Time: 1:58:35
# Num steps: 352256   Return: -65.4   Time: 1:59:21
# Num steps: 354304   Return: -13.5   Time: 1:59:59
# Num steps: 356352   Return: -65.4   Time: 2:00:40
# Num steps: 358400   Return: -65.4   Time: 2:01:41
# Num steps: 360448   Return: -65.4   Time: 2:02:19
# Num steps: 362496   Return: 252.9   Time: 2:02:55
# Num steps: 364544   Return: 668.2   Time: 2:03:32
# Num steps: 366592   Return: 661.2   Time: 2:04:09
# Num steps: 368640   Return: 277.2   Time: 2:04:47
# Num steps: 370688   Return: 228.7   Time: 2:05:25
# Num steps: 372736   Return: 239.1   Time: 2:06:03
# Num steps: 374784   Return: 772.0   Time: 2:06:41
# Num steps: 376832   Return: 173.4   Time: 2:07:19
# Num steps: 378880   Return: 156.1   Time: 2:07:57
# Num steps: 380928   Return: -51.6   Time: 2:08:35
# Num steps: 382976   Return: 266.8   Time: 2:09:13
# Num steps: 385024   Return: 422.5   Time: 2:09:53
# Num steps: 387072   Return: 180.3   Time: 2:10:32
# Num steps: 389120   Return: 259.9   Time: 2:11:10
# Num steps: 391168   Return: 246.0   Time: 2:11:46
# Num steps: 393216   Return: 301.4   Time: 2:12:25
# Num steps: 395264   Return: 284.1   Time: 2:12:58
# Num steps: 397312   Return: -6.6    Time: 2:13:32
# Num steps: 399360   Return: 256.4   Time: 2:14:05
# Num steps: 401408   Return: 273.7   Time: 2:14:39
# Num steps: 403456   Return: 266.8   Time: 2:15:13
# Num steps: 405504   Return: 263.3   Time: 2:15:47
# Num steps: 407552   Return: 266.8   Time: 2:16:20
# Num steps: 409600   Return: 263.3   Time: 2:16:54
# Num steps: 411648   Return: 688.9   Time: 2:17:29
# Num steps: 413696   Return: 384.4   Time: 2:18:03
# Num steps: 415744   Return: 733.9   Time: 2:18:38
# Num steps: 417792   Return: 398.3   Time: 2:19:11
# Num steps: 419840   Return: 903.4   Time: 2:19:45
# 最高スコアを記録: 903.4
# モデルを best_model_3 に保存しました。
# Num steps: 421888   Return: 834.3   Time: 2:20:19
# Num steps: 423936   Return: 893.1   Time: 2:20:53
# Num steps: 425984   Return: 817.0   Time: 2:21:27
# Num steps: 428032   Return: 813.5   Time: 2:22:01
# Num steps: 430080   Return: 796.2   Time: 2:22:35
# Num steps: 432128   Return: 772.0   Time: 2:23:08
# Num steps: 434176   Return: 810.0   Time: 2:23:43
# Num steps: 436224   Return: 304.8   Time: 2:24:17
# Num steps: 438272   Return: 830.8   Time: 2:24:50
# Num steps: 440320   Return: 277.2   Time: 2:25:24
# Num steps: 442368   Return: 844.6   Time: 2:25:58
# Num steps: 444416   Return: 778.9   Time: 2:26:32
# Num steps: 446464   Return: 761.6   Time: 2:27:06
# Num steps: 448512   Return: 367.1   Time: 2:27:39
# Num steps: 450560   Return: 367.1   Time: 2:28:13
# Num steps: 452608   Return: 699.3   Time: 2:28:54
# Num steps: 454656   Return: 287.5   Time: 2:29:34
# Num steps: 456704   Return: 284.1   Time: 2:30:12
# Num steps: 458752   Return: 387.9   Time: 2:30:48
# Num steps: 460800   Return: 730.4   Time: 2:31:26
# Num steps: 462848   Return: 287.5   Time: 2:32:03
# Num steps: 464896   Return: 173.4   Time: 2:32:39
# Num steps: 466944   Return: 291.0   Time: 2:33:19
# Num steps: 468992   Return: 284.1   Time: 2:33:55
# Num steps: 471040   Return: 754.7   Time: 2:34:32
# Num steps: 473088   Return: 675.1   Time: 2:35:09
# Num steps: 475136   Return: 432.9   Time: 2:35:47
# Num steps: 477184   Return: 221.8   Time: 2:36:24
# Num steps: 479232   Return: 287.5   Time: 2:37:00
# Num steps: 481280   Return: 692.4   Time: 2:37:35
# Num steps: 483328   Return: 301.4   Time: 2:38:11
# Num steps: 485376   Return: 692.4   Time: 2:38:46
# Num steps: 487424   Return: 256.4   Time: 2:39:20
# Num steps: 489472   Return: 578.2   Time: 2:39:53
# Num steps: 491520   Return: 10.7    Time: 2:40:38
# Num steps: 493568   Return: 266.8   Time: 2:41:18
# Num steps: 495616   Return: 256.4   Time: 2:42:02
# Num steps: 497664   Return: 640.5   Time: 2:42:44
# Num steps: 499712   Return: 796.2   Time: 2:43:26

# %%
trainer.plot()

# %%
env.close()
env_test.close()

# %%
env = gym.make('CarRacing-v3', render_mode='rgb_array', max_episode_steps=3000)
best_ppo_algo = PPO(
    state_shape=env.observation_space.shape,
    action_shape=env.action_space.shape,
    seed=SEED,
    device=torch.device("cuda" if torch.cuda.is_available() else "cpu")
)

best_ppo_algo.load_models('best_ppo_1')

video_folder = "best_ppo_1_videos"
env = RecordVideo(env, video_folder, episode_trigger=lambda e: True)
state, _ = env.reset(seed=1)
done = False
while not done:
    action = best_ppo_algo.exploit(state)
    state, _, terminated, truncated, _ = env.step(action)
    done = terminated or truncated
env.close()


play_mp4(video_folder)
# Out:
# モデルを best_ppo_1 から読み込みました。
# /opt/miniconda3/envs/car-racing-env/lib/python3.10/site-packages/gymnasium/wrappers/rendering.py:293: UserWarning: WARN: Overwriting existing videos at /Users/todayuto/Downloads/best_ppo_1_videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# 表示中の動画: best_ppo_1_videos/rl-video-episode-0.mp4
#     <video width=600 controls>
#         <source src="data:video/mp4;base64,..." type="video/mp4">
#     </video>

# %%
env = gym.make('CarRacing-v3', render_mode='rgb_array', max_episode_steps=3000)
best_ppo_algo = PPO(
    state_shape=env.observation_space.shape,
    action_shape=env.action_space.shape,
    seed=SEED,
    device=torch.device("cuda" if torch.cuda.is_available() else "cpu")
)

best_ppo_algo.load_models('best_ppo_1')
# Out:
# モデルを best_ppo_1 から読み込みました。

# %%
class CriticOutputWrapper(torch.nn.Module):
        def __init__(self, cnn, critic):
            super().__init__()
            self.cnn = cnn
            self.critic = critic
        def forward(self, x):
            features = self.cnn(x)
            return self.critic(features)

# %%
def visualize_grad_cam(algo, state, device):
    model = algo.cnn
    target_layers = [model.net[4]]

    cam_model = CriticOutputWrapper(algo.cnn, algo.critic)
    cam = GradCAM(model=cam_model, target_layers=target_layers)

    input_tensor = preprocess_state(state, device)
    grayscale_cam = cam(input_tensor=input_tensor)[0, :]

    rgb_img = state / 255.0
    visualization = show_cam_on_image(rgb_img, grayscale_cam, use_rgb=True)

    return visualization

# %%
states_to_visualize = []
timestamps = [100, 200, 300, 400, 500, 600] 

vis_env = gym.make('CarRacing-v3', render_mode='rgb_array')
state, _ = vis_env.reset(seed=1)

for i in range(1, max(timestamps) + 1):
    action = best_ppo_algo.exploit(state)
    state, _, done, _, _ = vis_env.step(action)
    if i in timestamps:
        states_to_visualize.append((i, state.copy()))
        print(f"  - ステップ {i} の画像を保存しました。")
    if done:
        break
vis_env.close()


num_images = len(states_to_visualize)
rows = (num_images + 2) // 3
fig, axes = plt.subplots(rows, 3, figsize=(15, 5 * rows))
axes = axes.flatten()

for i, (step_num, captured_state) in enumerate(states_to_visualize):
    vis_image = visualize_grad_cam(best_ppo_algo, captured_state, best_ppo_algo.device)

    ax = axes[i]
    ax.imshow(vis_image)
    ax.set_title(f"Step: {step_num}")
    ax.axis('off')

for j in range(num_images, len(axes)):
    axes[j].axis('off')

plt.tight_layout()
plt.show()

# %%
class PPO(Algorithm):
    def __init__(self, state_shape, action_shape, device, seed=0,
                 batch_size=256, gamma=0.99, lr=3e-5,
                 rollout_length=2048, num_updates=10, clip_eps=0.15, lambd=0.95,
                 coef_ent=0.01, max_grad_norm=0.5):
        super().__init__()
        torch.manual_seed(seed)
        if device.type == 'cuda': torch.cuda.manual_seed(seed)
        np.random.seed(seed)

        self.buffer = RolloutBuffer(rollout_length, state_shape, action_shape, device)
        self.device = device

        dummy_state = torch.zeros(1, state_shape[2], state_shape[0], state_shape[1], device=device)
        self.cnn = CNN(input_channels=state_shape[2]).to(device)
        cnn_output_dim = self.cnn(dummy_state).shape[-1]
        self.actor = PPOActor(cnn_output_dim, action_shape).to(device)
        self.critic = PPOCritic(cnn_output_dim).to(device)
        self.optim = torch.optim.Adam(list(self.cnn.parameters()) + list(self.actor.parameters()) + list(self.critic.parameters()), lr=lr)

        self.batch_size = batch_size
        self.gamma = gamma
        self.rollout_length = rollout_length
        self.num_updates = num_updates
        self.clip_eps = clip_eps
        self.lambd = lambd
        self.coef_ent = coef_ent
        self.max_grad_norm = max_grad_norm

        self.off_course_threshold = 100
        self.off_course_counter = 0


    def explore(self, state):
        state_tensor = preprocess_state(state, self.device)
        with torch.no_grad():
            features = self.cnn(state_tensor)
            action, log_pi = self.actor.sample(features)
        return action.cpu().numpy()[0], log_pi.item()

    def exploit(self, state):
        state_tensor = preprocess_state(state, self.device)
        with torch.no_grad():
            features = self.cnn(state_tensor)
            action = self.actor(features)
        return action.cpu().numpy()[0]

    def is_update(self, steps):
        return steps % self.rollout_length == 0

    def step(self, env, state, t, steps):
        t += 1
        action, log_pi = self.explore(state)
        next_state, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated

        if reward < 0:
            self.off_course_counter += 1
        else:
            self.off_course_counter = 0

        if self.off_course_counter >= self.off_course_threshold:
            done = True
            reward = -100

        done_masked = done if not truncated else False
        self.buffer.append(state, action, reward, done_masked, log_pi)

        if done:
            t = 0
            next_state, _ = env.reset()
            self.off_course_counter = 0

        return next_state, t

    def update(self):
        states, actions, rewards, dones, log_pis_old = self.buffer.get()
        processed_states = states.float().permute(0, 3, 1, 2) / 255.0

        with torch.no_grad():
            features = self.cnn(processed_states)
            values = self.critic(features)
            next_features = self.cnn(torch.roll(processed_states, -1, 0))
            next_values = self.critic(next_features)

        targets, advantages = calculate_advantage(values, rewards, dones, next_values, self.gamma, self.lambd)

        for _ in range(self.num_updates):
            indices = np.random.permutation(self.rollout_length)
            for start in range(0, self.rollout_length, self.batch_size):
                idx = indices[start:start+self.batch_size]
                features_batch = self.cnn(processed_states[idx])

                values_new_batch = self.critic(features_batch)
                values_old_batch = values[idx]

                values_clipped = values_old_batch + torch.clamp(
                    values_new_batch - values_old_batch, -self.clip_eps, self.clip_eps
                )

                loss_critic_unclipped = (values_new_batch - targets[idx]).pow(2)
                loss_critic_clipped = (values_clipped - targets[idx]).pow(2)

                loss_critic = 0.5 * torch.max(loss_critic_unclipped, loss_critic_clipped).mean()

                log_pis = evaluate_lop_pi(self.actor.fc(features_batch), self.actor.log_stds, actions[idx])
                mean_entropy = -log_pis.mean()
                ratios = (log_pis - log_pis_old[idx]).exp()
                loss_actor1 = -ratios * advantages[idx]
                loss_actor2 = -torch.clamp(ratios, 1.0 - self.clip_eps, 1.0 + self.clip_eps) * advantages[idx]
                loss_actor = torch.max(loss_actor1, loss_actor2).mean() - self.coef_ent * mean_entropy

                total_loss = loss_actor + 0.5 * loss_critic

                self.optim.zero_grad()
                total_loss.backward()
                nn.utils.clip_grad_norm_(self.cnn.parameters(), self.max_grad_norm)
                nn.utils.clip_grad_norm_(self.actor.parameters(), self.max_grad_norm)
                nn.utils.clip_grad_norm_(self.critic.parameters(), self.max_grad_norm)
                self.optim.step()

    def save_models(self, save_dir):
        """モデルの重みを保存する"""
        if not os.path.exists(save_dir):
            os.makedirs(save_dir)
        torch.save(self.cnn.state_dict(), os.path.join(save_dir, 'cnn.pth'))
        torch.save(self.actor.state_dict(), os.path.join(save_dir, 'actor.pth'))
        torch.save(self.critic.state_dict(), os.path.join(save_dir, 'critic.pth'))
        print(f"モデルを {save_dir} に保存しました。")

    def load_models(self, load_dir):
        """モデルの重みを読み込む"""
        self.cnn.load_state_dict(torch.load(os.path.join(load_dir, 'cnn.pth')))
        self.actor.load_state_dict(torch.load(os.path.join(load_dir, 'actor.pth')))
        self.critic.load_state_dict(torch.load(os.path.join(load_dir, 'critic.pth')))
        print(f"モデルを {load_dir} から読み込みました。")

# %%
SEED = 0
NUM_STEPS = 5 * 10**5
EVAL_INTERVAL = 2048

env = gym.make('CarRacing-v3', render_mode='rgb_array', max_episode_steps=1000)
env_test = gym.make('CarRacing-v3', render_mode='rgb_array', max_episode_steps=1000)

algo = PPO(
    state_shape=env.observation_space.shape,
    action_shape=env.action_space.shape,
    seed=SEED,
    device=torch.device("cuda" if torch.cuda.is_available() else "cpu"),
    reward_scaling=False
)

trainer = Trainer(
    env=env,
    env_test=env_test,
    algo=algo,
    seed=SEED,
    num_steps=NUM_STEPS,
    eval_interval=EVAL_INTERVAL,
    model_dir='best_ppo_2'
)

# %%
trainer.train()
# Out:
# Num steps: 2048     Return: -41.2   Time: 0:00:31
# 最高スコアを記録: -41.2
# モデルを best_ppo_2 に保存しました。
# Num steps: 4096     Return: -78.9   Time: 0:00:52
# Num steps: 6144     Return: -58.5   Time: 0:01:24
# Num steps: 8192     Return: -65.4   Time: 0:01:55
# Num steps: 10240    Return: -61.9   Time: 0:02:27
# Num steps: 12288    Return: -64.7   Time: 0:02:49
# Num steps: 14336    Return: -61.9   Time: 0:03:20
# Num steps: 16384    Return: -27.3   Time: 0:03:52
# 最高スコアを記録: -27.3
# モデルを best_ppo_2 に保存しました。
# Num steps: 18432    Return: -70.0   Time: 0:04:17
# Num steps: 20480    Return: -60.7   Time: 0:04:41
# Num steps: 22528    Return: -50.4   Time: 0:05:07
# Num steps: 24576    Return: 34.9    Time: 0:05:46
# 最高スコアを記録: 34.9
# モデルを best_ppo_2 に保存しました。
# Num steps: 26624    Return: 225.3   Time: 0:06:22
# 最高スコアを記録: 225.3
# モデルを best_ppo_2 に保存しました。
# Num steps: 28672    Return: 249.5   Time: 0:06:57
# 最高スコアを記録: 249.5
# モデルを best_ppo_2 に保存しました。
# Num steps: 30720    Return: 7.3     Time: 0:07:32
# Num steps: 32768    Return: 211.4   Time: 0:08:10
# Num steps: 34816    Return: 187.2   Time: 0:08:46
# Num steps: 36864    Return: 246.0   Time: 0:09:22
# Num steps: 38912    Return: 228.7   Time: 0:10:00
# Num steps: 40960    Return: 204.5   Time: 0:10:44
# Num steps: 43008    Return: 93.8    Time: 0:11:22
# Num steps: 45056    Return: 41.9    Time: 0:12:02
# Num steps: 47104    Return: 7.3     Time: 0:12:41
# Num steps: 49152    Return: 218.3   Time: 0:13:20
# Num steps: 51200    Return: 10.7    Time: 0:13:58
# Num steps: 53248    Return: 55.7    Time: 0:14:41
# Num steps: 55296    Return: 79.9    Time: 0:15:20
# Num steps: 57344    Return: 252.9   Time: 0:15:59
# 最高スコアを記録: 252.9
# モデルを best_ppo_2 に保存しました。
# Num steps: 59392    Return: 252.9   Time: 0:16:37
# Num steps: 61440    Return: 252.9   Time: 0:17:14
# Num steps: 63488    Return: 252.9   Time: 0:17:52
# Num steps: 65536    Return: 252.9   Time: 0:18:33
# Num steps: 67584    Return: 252.9   Time: 0:19:14
# Num steps: 69632    Return: 252.9   Time: 0:19:51
# Num steps: 71680    Return: 252.9   Time: 0:20:28
# Num steps: 73728    Return: 270.2   Time: 0:21:04
# 最高スコアを記録: 270.2
# モデルを best_ppo_2 に保存しました。
# Num steps: 75776    Return: 270.2   Time: 0:21:42
# 最高スコアを記録: 270.2
# モデルを best_ppo_2 に保存しました。
# Num steps: 77824    Return: 97.2    Time: 0:22:21
# Num steps: 79872    Return: 252.9   Time: 0:22:59
# Num steps: 81920    Return: 270.2   Time: 0:23:36
# 最高スコアを記録: 270.2
# モデルを best_ppo_2 に保存しました。
# Num steps: 83968    Return: 270.2   Time: 0:24:13
# Num steps: 86016    Return: 284.1   Time: 0:24:52
# 最高スコアを記録: 284.1
# モデルを best_ppo_2 に保存しました。
# Num steps: 88064    Return: 256.4   Time: 0:25:31
# Num steps: 90112    Return: 252.9   Time: 0:26:07
# Num steps: 92160    Return: 291.0   Time: 0:26:46
# 最高スコアを記録: 291.0
# モデルを best_ppo_2 に保存しました。
# Num steps: 94208    Return: 564.4   Time: 0:27:26
# 最高スコアを記録: 564.4
# モデルを best_ppo_2 に保存しました。
# Num steps: 96256    Return: 284.1   Time: 0:28:04
# Num steps: 98304    Return: 287.5   Time: 0:28:42
# Num steps: 100352   Return: 280.6   Time: 0:29:22
# Num steps: 102400   Return: 242.6   Time: 0:30:04
# Num steps: 104448   Return: 249.5   Time: 0:30:45
# Num steps: 106496   Return: 439.8   Time: 0:31:24
# Num steps: 108544   Return: 273.7   Time: 0:32:06
# Num steps: 110592   Return: 225.3   Time: 0:32:48
# Num steps: 112640   Return: 76.5    Time: 0:33:28
# Num steps: 114688   Return: 28.0    Time: 0:34:08
# Num steps: 116736   Return: 159.5   Time: 0:34:53
# Num steps: 118784   Return: 249.5   Time: 0:35:34
# Num steps: 120832   Return: 246.0   Time: 0:36:15
# Num steps: 122880   Return: 287.5   Time: 0:36:58
# Num steps: 124928   Return: 554.0   Time: 0:37:38
# Num steps: 126976   Return: 249.5   Time: 0:38:18
# Num steps: 129024   Return: 280.6   Time: 0:38:59
# Num steps: 131072   Return: 381.0   Time: 0:39:38
# Num steps: 133120   Return: 277.2   Time: 0:40:16
# Num steps: 135168   Return: 266.8   Time: 0:40:54
# Num steps: 137216   Return: 69.6    Time: 0:41:32
# Num steps: 139264   Return: 128.4   Time: 0:42:11
# Num steps: 141312   Return: 17.6    Time: 0:42:50
# Num steps: 143360   Return: 10.7    Time: 0:43:27
# Num steps: 145408   Return: 239.1   Time: 0:44:04
# Num steps: 147456   Return: 34.9    Time: 0:44:42
# Num steps: 149504   Return: 266.8   Time: 0:45:21
# Num steps: 151552   Return: 246.0   Time: 0:45:57
# Num steps: 153600   Return: 242.6   Time: 0:46:30
# Num steps: 155648   Return: 526.3   Time: 0:47:03
# Num steps: 157696   Return: 246.0   Time: 0:47:37
# Num steps: 159744   Return: 221.8   Time: 0:48:11
# Num steps: 161792   Return: 235.6   Time: 0:48:46
# Num steps: 163840   Return: 256.4   Time: 0:49:23
# Num steps: 165888   Return: 263.3   Time: 0:49:57
# Num steps: 167936   Return: 221.8   Time: 0:50:33
# Num steps: 169984   Return: 266.8   Time: 0:51:10
# Num steps: 172032   Return: 232.2   Time: 0:51:48
# Num steps: 174080   Return: 259.9   Time: 0:52:26
# Num steps: 176128   Return: 34.9    Time: 0:53:01
# Num steps: 178176   Return: 45.3    Time: 0:53:37
# Num steps: 180224   Return: 291.0   Time: 0:54:14
# Num steps: 182272   Return: 259.9   Time: 0:54:51
# Num steps: 184320   Return: 287.5   Time: 0:55:27
# Num steps: 186368   Return: 156.8   Time: 0:55:58
# Num steps: 188416   Return: 34.9    Time: 0:56:34
# Num steps: 190464   Return: 232.2   Time: 0:57:09
# Num steps: 192512   Return: 197.6   Time: 0:57:44
# Num steps: 194560   Return: 256.4   Time: 0:58:18
# Num steps: 196608   Return: 24.6    Time: 0:58:52
# Num steps: 198656   Return: 252.9   Time: 0:59:27
# Num steps: 200704   Return: 256.4   Time: 1:00:01
# Num steps: 202752   Return: 259.9   Time: 1:00:36
# Num steps: 204800   Return: 225.3   Time: 1:01:11
# Num steps: 206848   Return: 228.7   Time: 1:01:46
# Num steps: 208896   Return: 239.1   Time: 1:02:22
# Num steps: 210944   Return: 166.4   Time: 1:02:56
# Num steps: 212992   Return: 263.3   Time: 1:03:30
# Num steps: 215040   Return: 239.1   Time: 1:04:06
# Num steps: 217088   Return: 581.7   Time: 1:04:42
# 最高スコアを記録: 581.7
# モデルを best_ppo_2 に保存しました。
# Num steps: 219136   Return: 263.3   Time: 1:05:21
# Num steps: 221184   Return: 252.9   Time: 1:06:01
# Num steps: 223232   Return: 263.3   Time: 1:06:37
# Num steps: 225280   Return: 259.9   Time: 1:07:12
# Num steps: 227328   Return: 239.1   Time: 1:07:48
# Num steps: 229376   Return: 62.6    Time: 1:08:23
# Num steps: 231424   Return: 242.6   Time: 1:08:57
# Num steps: 233472   Return: 287.5   Time: 1:09:33
# Num steps: 235520   Return: 239.1   Time: 1:10:13
# Num steps: 237568   Return: 131.8   Time: 1:10:50
# Num steps: 239616   Return: 225.3   Time: 1:11:26
# Num steps: 241664   Return: 221.8   Time: 1:12:01
# Num steps: 243712   Return: 235.6   Time: 1:12:36
# Num steps: 245760   Return: 242.6   Time: 1:13:11
# Num steps: 247808   Return: 228.7   Time: 1:13:47
# Num steps: 249856   Return: 266.8   Time: 1:14:23
# Num steps: 251904   Return: 249.5   Time: 1:14:59
# Num steps: 253952   Return: 249.5   Time: 1:15:36
# Num steps: 256000   Return: 263.3   Time: 1:16:11
# Num steps: 258048   Return: 256.4   Time: 1:16:46
# Num steps: 260096   Return: 259.9   Time: 1:17:22
# Num steps: 262144   Return: 242.6   Time: 1:17:56
# Num steps: 264192   Return: 249.5   Time: 1:18:30
# Num steps: 266240   Return: 252.9   Time: 1:19:05
# Num steps: 268288   Return: 228.7   Time: 1:19:40
# Num steps: 270336   Return: 246.0   Time: 1:20:15
# Num steps: 272384   Return: 232.2   Time: 1:20:50
# Num steps: 274432   Return: 256.4   Time: 1:21:25
# Num steps: 276480   Return: 263.3   Time: 1:21:59
# Num steps: 278528   Return: 294.5   Time: 1:22:34
# Num steps: 280576   Return: 249.5   Time: 1:23:10
# Num steps: 282624   Return: 218.3   Time: 1:23:45
# Num steps: 284672   Return: 252.9   Time: 1:24:20
# Num steps: 286720   Return: 235.6   Time: 1:24:55
# Num steps: 288768   Return: 246.0   Time: 1:25:30
# Num steps: 290816   Return: 52.2    Time: 1:26:04
# Num steps: 292864   Return: 204.5   Time: 1:26:40
# Num steps: 294912   Return: 225.3   Time: 1:27:15
# Num steps: 296960   Return: 228.7   Time: 1:27:50
# Num steps: 299008   Return: 225.3   Time: 1:28:29
# Num steps: 301056   Return: 76.5    Time: 1:29:04
# Num steps: 303104   Return: 256.4   Time: 1:29:39
# Num steps: 305152   Return: 263.3   Time: 1:30:15
# Num steps: 307200   Return: 249.5   Time: 1:30:50
# Num steps: 309248   Return: 228.7   Time: 1:31:25
# Num steps: 311296   Return: 252.9   Time: 1:32:00
# Num steps: 313344   Return: 256.4   Time: 1:32:34
# Num steps: 315392   Return: 242.6   Time: 1:33:09
# Num steps: 317440   Return: 228.7   Time: 1:33:44
# Num steps: 319488   Return: 242.6   Time: 1:34:18
# Num steps: 321536   Return: 214.9   Time: 1:34:53
# Num steps: 323584   Return: 273.7   Time: 1:35:28
# Num steps: 325632   Return: 252.9   Time: 1:36:02
# Num steps: 327680   Return: 318.7   Time: 1:36:37
# Num steps: 329728   Return: 270.2   Time: 1:37:12
# Num steps: 331776   Return: 336.0   Time: 1:37:48
# Num steps: 333824   Return: 813.5   Time: 1:38:24
# 最高スコアを記録: 813.5
# モデルを best_ppo_2 に保存しました。
# Num steps: 335872   Return: 294.5   Time: 1:38:58
# Num steps: 337920   Return: 246.0   Time: 1:39:31
# Num steps: 339968   Return: 239.1   Time: 1:40:11
# Num steps: 342016   Return: 263.3   Time: 1:40:47
# Num steps: 344064   Return: 239.1   Time: 1:41:24
# Num steps: 346112   Return: 595.5   Time: 1:42:02
# Num steps: 348160   Return: 405.2   Time: 1:42:45
# Num steps: 350208   Return: 266.8   Time: 1:43:27
# Num steps: 352256   Return: 678.5   Time: 1:44:07
# Num steps: 354304   Return: 270.2   Time: 1:44:46
# Num steps: 356352   Return: 581.7   Time: 1:45:28
# Num steps: 358400   Return: 412.1   Time: 1:46:06
# Num steps: 360448   Return: 810.0   Time: 1:46:45
# Num steps: 362496   Return: 872.3   Time: 1:47:24
# 最高スコアを記録: 872.3
# モデルを best_ppo_2 に保存しました。
# Num steps: 364544   Return: 872.3   Time: 1:48:02
# 最高スコアを記録: 872.3
# モデルを best_ppo_2 に保存しました。
# Num steps: 366592   Return: 685.5   Time: 1:48:47
# Num steps: 368640   Return: 844.6   Time: 1:49:26
# Num steps: 370688   Return: 858.5   Time: 1:50:08
# Num steps: 372736   Return: 855.0   Time: 1:50:48
# Num steps: 374784   Return: 896.5   Time: 1:51:28
# 最高スコアを記録: 896.5
# モデルを best_ppo_2 に保存しました。
# Num steps: 376832   Return: 778.9   Time: 1:52:06
# Num steps: 378880   Return: 263.3   Time: 1:52:42
# Num steps: 380928   Return: 266.8   Time: 1:53:17
# Num steps: 382976   Return: 266.8   Time: 1:53:54
# Num steps: 385024   Return: 263.3   Time: 1:54:30
# Num steps: 387072   Return: 242.6   Time: 1:55:06
# Num steps: 389120   Return: 266.8   Time: 1:55:42
# Num steps: 391168   Return: 266.8   Time: 1:56:18
# Num steps: 393216   Return: 422.5   Time: 1:56:55
# Num steps: 395264   Return: 252.9   Time: 1:57:31
# Num steps: 397312   Return: 643.9   Time: 1:58:07
# Num steps: 399360   Return: 259.9   Time: 1:58:44
# Num steps: 401408   Return: 270.2   Time: 1:59:21
# Num steps: 403456   Return: 246.0   Time: 1:59:58
# Num steps: 405504   Return: 232.2   Time: 2:00:35
# Num steps: 407552   Return: 232.2   Time: 2:01:12
# Num steps: 409600   Return: 235.6   Time: 2:01:51
# Num steps: 411648   Return: 512.5   Time: 2:02:31
# Num steps: 413696   Return: 675.1   Time: 2:03:10
# Num steps: 415744   Return: 263.3   Time: 2:03:53
# Num steps: 417792   Return: 882.7   Time: 2:04:37
# Num steps: 419840   Return: 242.6   Time: 2:05:20
# Num steps: 421888   Return: 259.9   Time: 2:06:04
# Num steps: 423936   Return: 263.3   Time: 2:06:46
# Num steps: 425984   Return: 228.7   Time: 2:07:28
# Num steps: 428032   Return: 259.9   Time: 2:08:06
# Num steps: 430080   Return: 232.2   Time: 2:08:44
# Num steps: 432128   Return: 246.0   Time: 2:09:28
# Num steps: 434176   Return: 259.9   Time: 2:10:11
# Num steps: 436224   Return: -27.3   Time: 2:10:51
# Num steps: 438272   Return: -44.6   Time: 2:11:33
# Num steps: 440320   Return: 28.0    Time: 2:12:16
# Num steps: 442368   Return: -34.3   Time: 2:12:54
# Num steps: 444416   Return: 242.6   Time: 2:13:37
# Num steps: 446464   Return: 273.7   Time: 2:14:16
# Num steps: 448512   Return: 252.9   Time: 2:14:56
# Num steps: 450560   Return: 249.5   Time: 2:15:34
# Num steps: 452608   Return: 259.9   Time: 2:16:12
# Num steps: 454656   Return: 259.9   Time: 2:16:49
# Num steps: 456704   Return: 405.2   Time: 2:17:32
# Num steps: 458752   Return: 256.4   Time: 2:18:12
# Num steps: 460800   Return: 235.6   Time: 2:18:51
# Num steps: 462848   Return: 401.7   Time: 2:19:31
# Num steps: 464896   Return: 242.6   Time: 2:20:09
# Num steps: 466944   Return: 263.3   Time: 2:20:46
# Num steps: 468992   Return: 855.0   Time: 2:21:25
# Num steps: 471040   Return: 256.4   Time: 2:22:02
# Num steps: 473088   Return: 259.9   Time: 2:22:36
# Num steps: 475136   Return: 263.3   Time: 2:23:16
# Num steps: 477184   Return: 256.4   Time: 2:23:53
# Num steps: 479232   Return: -44.6   Time: 2:24:33
# Num steps: 481280   Return: -61.9   Time: 2:25:11
# Num steps: 483328   Return: 232.2   Time: 2:25:51
# Num steps: 485376   Return: 235.6   Time: 2:26:32
# Num steps: 487424   Return: 235.6   Time: 2:27:10
# Num steps: 489472   Return: 266.8   Time: 2:27:52
# Num steps: 491520   Return: 723.5   Time: 2:28:33
# Num steps: 493568   Return: 263.3   Time: 2:29:15
# Num steps: 495616   Return: 263.3   Time: 2:29:59
# Num steps: 497664   Return: 270.2   Time: 2:30:41
# Num steps: 499712   Return: 239.1   Time: 2:31:22

# %%
trainer.plot()

# %%
env.close()
env_test.close()

# %%
env = gym.make('CarRacing-v3', render_mode='rgb_array', max_episode_steps=1000)
best_ppo_algo = PPO(
    state_shape=env.observation_space.shape,
    action_shape=env.action_space.shape,
    seed=SEED,
    device=torch.device("cuda" if torch.cuda.is_available() else "cpu")
)

best_ppo_algo.load_models('best_ppo_2')

video_folder = "best_ppo_2_videos"
env = RecordVideo(env, video_folder, episode_trigger=lambda e: True)
state, _ = env.reset(seed=4)
done = False
while not done:
    action = best_ppo_algo.exploit(state)
    state, _, terminated, truncated, _ = env.step(action)
    done = terminated or truncated
env.close()

play_mp4(video_folder)
# Out:
# モデルを best_ppo_2 から読み込みました。
# /opt/miniconda3/envs/car-racing-env/lib/python3.10/site-packages/gymnasium/wrappers/rendering.py:293: UserWarning: WARN: Overwriting existing videos at /Users/todayuto/Downloads/best_ppo_2_videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# 表示中の動画: best_ppo_2_videos/rl-video-episode-0.mp4
#     <video width=600 controls>
#         <source src="data:video/mp4;base64,..." type="video/mp4">
#     </video>

# %%
class PPO(Algorithm):
    def __init__(self, state_shape, action_shape, device, seed=0,
                 batch_size=256, gamma=0.99, lr=3e-5,
                 rollout_length=2048, num_updates=10, clip_eps=0.2, lambd=0.95,
                 coef_ent=0.01, max_grad_norm=0.5, num_steps=10**6):
        super().__init__()
        torch.manual_seed(seed)
        if device.type == 'cuda': torch.cuda.manual_seed(seed)
        np.random.seed(seed)

        self.buffer = RolloutBuffer(rollout_length, state_shape, action_shape, device)
        self.device = device

        dummy_state = torch.zeros(1, state_shape[2], state_shape[0], state_shape[1], device=device)
        self.cnn_actor = CNN(input_channels=state_shape[2]).to(device)
        self.cnn_critic = CNN(input_channels=state_shape[2]).to(device)

        cnn_output_dim = self.cnn_actor(dummy_state).shape[-1]
        self.actor = PPOActor(cnn_output_dim, action_shape).to(device)
        self.critic = PPOCritic(cnn_output_dim).to(device)
        self.optim = torch.optim.Adam(list(self.cnn_actor.parameters()) + list(self.cnn_critic.parameters()) + list(self.actor.parameters()) + list(self.critic.parameters()), lr=lr, eps=1e-5)
        total_updates = num_steps // rollout_length
        
        self.scheduler = LinearLR(
            self.optim,
            start_factor=1.0,
            end_factor=0.0,
            total_iters=total_updates
        )

        self.batch_size = batch_size
        self.gamma = gamma
        self.rollout_length = rollout_length
        self.num_updates = num_updates
        self.clip_eps = clip_eps
        self.lambd = lambd
        self.coef_ent = coef_ent
        self.max_grad_norm = max_grad_norm
        if self.reward_scaling:
            self.reward_rms = RunningMeanStd(shape=(1,))

        self.off_course_threshold = 100
        self.off_course_counter = 0


    def explore(self, state):
        state_tensor = preprocess_state(state, self.device)
        with torch.no_grad():
            features = self.cnn_actor(state_tensor)
            action, log_pi = self.actor.sample(features)
        return action.cpu().numpy()[0], log_pi.item()

    def exploit(self, state):
        state_tensor = preprocess_state(state, self.device)
        with torch.no_grad():
            features = self.cnn_actor(state_tensor)
            action = self.actor(features)
        return action.cpu().numpy()[0]

    def is_update(self, steps):
        return steps % self.rollout_length == 0

    def step(self, env, state, t, steps):
        t += 1
        action, log_pi = self.explore(state)
        next_state, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated

        if reward < 0:
            self.off_course_counter += 1
        else:
            self.off_course_counter = 0

        if self.off_course_counter >= self.off_course_threshold:
            done = True
            reward = -100

        done_masked = done if not truncated else False
        self.buffer.append(state, action, reward, done_masked, log_pi)

        if done:
            t = 0
            next_state, _ = env.reset()
            self.off_course_counter = 0

        return next_state, t

    def update(self):
        states, actions, rewards, dones, log_pis_old = self.buffer.get()
        processed_states = states.float().permute(0, 3, 1, 2) / 255.0

        with torch.no_grad():
            features_critic = self.cnn_critic(processed_states)
            values = self.critic(features_critic)
            next_features_critic = self.cnn_critic(torch.roll(processed_states, -1, 0))
            next_values = self.critic(next_features_critic)

        targets, advantages = calculate_advantage(values, rewards, dones, next_values, self.gamma, self.lambd)

        for _ in range(self.num_updates):
            indices = np.random.permutation(self.rollout_length)
            for start in range(0, self.rollout_length, self.batch_size):
                idx = indices[start:start+self.batch_size]
                features_actor_batch = self.cnn_actor(processed_states[idx])
                features_critic_batch = self.cnn_critic(processed_states[idx])

                values_new_batch = self.critic(features_critic_batch)
                values_old_batch = values[idx]

                values_clipped = values_old_batch + torch.clamp(
                    values_new_batch - values_old_batch, -self.clip_eps, self.clip_eps
                )

                loss_critic_unclipped = (values_new_batch - targets[idx]).pow(2)
                loss_critic_clipped = (values_clipped - targets[idx]).pow(2)

                loss_critic = 0.5 * torch.max(loss_critic_unclipped, loss_critic_clipped).mean()

                log_pis = evaluate_lop_pi(self.actor.fc(features_actor_batch), self.actor.log_stds, actions[idx])
                mean_entropy = -log_pis.mean()
                ratios = (log_pis - log_pis_old[idx]).exp()
                loss_actor1 = -ratios * advantages[idx]
                loss_actor2 = -torch.clamp(ratios, 1.0 - self.clip_eps, 1.0 + self.clip_eps) * advantages[idx]
                loss_actor = torch.max(loss_actor1, loss_actor2).mean() - self.coef_ent * mean_entropy

                total_loss = loss_actor + 0.5 * loss_critic

                self.optim.zero_grad()
                total_loss.backward()
                nn.utils.clip_grad_norm_(self.cnn_actor.parameters(), self.max_grad_norm)
                nn.utils.clip_grad_norm_(self.cnn_critic.parameters(), self.max_grad_norm)
                nn.utils.clip_grad_norm_(self.actor.parameters(), self.max_grad_norm)
                nn.utils.clip_grad_norm_(self.critic.parameters(), self.max_grad_norm)
                self.optim.step()
        
        self.scheduler.step()

    def save_models(self, save_dir):
        if not os.path.exists(save_dir):
            os.makedirs(save_dir)
        torch.save(self.cnn_actor.state_dict(), os.path.join(save_dir, 'cnn_actor.pth'))
        torch.save(self.cnn_critic.state_dict(), os.path.join(save_dir, 'cnn_critic.pth'))
        torch.save(self.actor.state_dict(), os.path.join(save_dir, 'actor.pth'))
        torch.save(self.critic.state_dict(), os.path.join(save_dir, 'critic.pth'))
        print(f"モデルを {save_dir} に保存しました。")

    def load_models(self, load_dir):
        self.cnn_actor.load_state_dict(torch.load(os.path.join(load_dir, 'cnn_actor.pth')))
        self.cnn_critic.load_state_dict(torch.load(os.path.join(load_dir, 'cnn_critic.pth')))
        self.actor.load_state_dict(torch.load(os.path.join(load_dir, 'actor.pth')))
        self.critic.load_state_dict(torch.load(os.path.join(load_dir, 'critic.pth')))
        print(f"モデルを {load_dir} から読み込みました。")

# %%
SEED = 0
NUM_STEPS = 5 * 10**5
EVAL_INTERVAL = 512

env = gym.make('CarRacing-v3', render_mode='rgb_array', max_episode_steps=1000)
env_test = gym.make('CarRacing-v3', render_mode='rgb_array', max_episode_steps=1000)

algo = PPO(
    state_shape=env.observation_space.shape,
    action_shape=env.action_space.shape,
    seed=SEED,
    device=torch.device("cuda" if torch.cuda.is_available() else "cpu"),
    reward_scaling=False,
    num_steps=NUM_STEPS
)

trainer = Trainer(
    env=env,
    env_test=env_test,
    algo=algo,
    seed=SEED,
    num_steps=NUM_STEPS,
    eval_interval=EVAL_INTERVAL,
    model_dir='best_ppo_3'
)

# %%
trainer.train()

# %%
trainer.plot()

# %%
env.close()
env_test.close()

# %%
env = gym.make('CarRacing-v3', render_mode='rgb_array', max_episode_steps=1000)
best_ppo_algo = PPO(
    state_shape=env.observation_space.shape,
    action_shape=env.action_space.shape,
    seed=SEED,
    device=torch.device("cuda" if torch.cuda.is_available() else "cpu")
)

best_ppo_algo.load_models('best_ppo_3')

video_folder = "best_ppo_3_videos"
env = RecordVideo(env, video_folder, episode_trigger=lambda e: True)
state, _ = env.reset(seed=SEED)
done = False
while not done:
    action = best_ppo_algo.exploit(state)
    state, _, terminated, truncated, _ = env.step(action)
    done = terminated or truncated
env.close()

play_mp4(video_folder)
# Out:
# モデルを best_ppo_3 から読み込みました。
# /opt/miniconda3/envs/car-racing-env/lib/python3.10/site-packages/gymnasium/wrappers/rendering.py:293: UserWarning: WARN: Overwriting existing videos at /Users/todayuto/Downloads/best_ppo_3_videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# 表示中の動画: best_ppo_3_videos/rl-video-episode-0.mp4
#     <video width=600 controls>
#         <source src="data:video/mp4;base64,..." type="video/mp4">
#     </video>
